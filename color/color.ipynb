# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
im = Image.open("sample.png")

# %%
data = np.asarray(im)

# %%
data.shape
# Out:
# (488, 617, 3)

# %%
im = im.resize((400,400*488//617))

# %%
for i in range(len(data)):
    if data[i][300][0]==255:
        print(i)
# Out:
# 138
# 139
# 140
# 267
# 268
# 269

# %%
t_data = data[150]
for i in range(len(data[1])):
    if t_data[i][0]==255:
        print(i)
# Out:
# 110
# 111
# 112
# 493
# 494
# 495

# %%
sample1, sample2 = data[141][113:493], data[270][113:493]

# %%
plt.subplot(121)
plt.plot(sample1[:,0],'r')
plt.plot(sample1[:,1],'g')
plt.plot(sample1[:,2],'b')
plt.subplot(122)
plt.plot(sample2[:,0],'r')
plt.plot(sample2[:,1],'g')
plt.plot(sample2[:,2],'b')
plt.show()
im
# Out:
# <PIL.Image.Image image mode=RGB size=400x316 at 0x17623329A00>

# %%
block = data[141:267,113:493,:]
print(block.shape)
# Out:
# (488, 617, 3)
# (126, 380, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.gca(projection='3d')

Y = np.arange(141,267)
X = np.arange(113, 493)
#X, Z = np.meshgrid(X,np.zeros(380))
#Z, Y = np.meshgrid(np.zeros(126),Y)
X, Y = np.meshgrid(X,Y)

Z = block[:,:,0]
surf = ax.plot_surface(X, Y, Z, color='red',linewidth=0, antialiased=True)

Z = block[:,:,1]
surf = ax.plot_surface(X, Y, Z, color='green',linewidth=0, antialiased=True)

Z = block[:,:,2]
surf = ax.plot_surface(X, Y, Z, color='blue',linewidth=0, antialiased=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
